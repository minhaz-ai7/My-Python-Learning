# %%
student = ('minhaz', 20 , 'rajshahi')
name , age , city = student 

# print(len(student))
# print(20 in student)

# for x in student:
#     print(x)

print(name)
print(age)
print(city)
# Out:
# minhaz
# 20
# rajshahi

# %%
marks = (94 , 97)
x , y = marks

print("\nx =",x*x)
print("\ny =",y-x)
# Out:
# x = 8836
#
# y = 3

# %%
def get_user():
    return("Minhaz",21)
name, age = get_user()

print(name , age)
# Out:
# Minhaz 21

# %%
colors = 'red','green'
red, green = colors 

# for x in colors:
#         print(x)

print(f"coors:{red} , color: {green}")
# Out:
# coors:red , color: green

# %%
my_tuple = (1,3,4,56,6)
my_list = tuple(my_tuple)
